# %%
import json
import requests

# %%
path = "https://economia.awesomeapi.com.br/last/USD-BRL,EUR-BRL,BTC-BRL" #Armazenando API em path

cotacao = requests.get(path) #Chamando a API

cotacao = cotacao.json() #Visualizando API em JSON

print(cotacao)
# Out:
# {'USDBRL': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.6239', 'low': '5.61128', 'varBid': '0.0009', 'pctChange': '0.016017', 'bid': '5.6196', 'ask': '5.6226', 'timestamp': '1745978972', 'create_date': '2025-04-29 23:09:32'}, 'EURBRL': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.39795', 'low': '6.37349', 'varBid': '-0.008159', 'pctChange': '-0.127689', 'bid': '6.38162', 'ask': '6.39795', 'timestamp': '1745978919', 'create_date': '2025-04-29 23:08:39'}, 'BTCBRL': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '540355', 'low': '529599', 'varBid': '-2808', 'pctChange': '-0.522', 'bid': '534735', 'ask': '534736', 'timestamp': '1745978978', 'create_date': '2025-04-29 23:09:38'}}

# %%
print(cotacao['USDBRL']) #visualizando tudo sobre 'USDBRL' (Dolar)
# Out:
# {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.6239', 'low': '5.61128', 'varBid': '0.0009', 'pctChange': '0.016017', 'bid': '5.6196', 'ask': '5.6226', 'timestamp': '1745978972', 'create_date': '2025-04-29 23:09:32'}

# %%
print(cotacao['USDBRL']['bid']) #Exibindo cotacao do dolar
# Out:
# 5.6196
